# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
from pandas.tools.plotting import radviz

# %%
df = pd.read_csv("CONSULTA-LUGAR-DE-APLICACION-EVALUACION-PSc-QSM6.csv", encoding='latin-1',skiprows=[41432])

# %%
df.keys()
# Out:
# Index(['Cedula', 'HORA', 'NUM LABORATORIO', 'Num_dia', 'Nombre', 'Provincia',
#        'Canton', 'Parroquia', 'Zona', 'Nombre_institucion', 'Amie_institucion',
#        'DIRECCION', 'tipo_prueba'],
#       dtype='object')

# %%
df
# Out:
#            Cedula                                               HORA  \
# 0       103847794                                      09H45 - 11H30
# 1       201481017                                      09H45 - 11H30
# 2       400733200                                      09H45 - 11H30
# 3       400811774                                      09H45 - 11H30
# 4       400839049                                      09H45 - 11H30
# 5       400910527                                      09H45 - 11H30
# 6       400911731                                      09H45 - 11H30
# 7       400936829                                      09H45 - 11H30
# 8       401034764                                      09H45 - 11H30
# 9       401043757                                      09H45 - 11H30
# 10      401045356                                      09H45 - 11H30
# 11      401047238                                      09H45 - 11H30
# 12      401078605                                      09H45 - 11H30
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41433 entries, 0 to 41432
# Data columns (total 13 columns):
# Cedula                41433 non-null int64
# HORA                  41433 non-null object
# NUM LABORATORIO       41433 non-null object
# Num_dia               41433 non-null object
# Nombre                41433 non-null object
# Provincia             41433 non-null object
# Canton                41433 non-null object
# Parroquia             41433 non-null object
# Zona                  41433 non-null object
# Nombre_institucion    41433 non-null object
# Amie_institucion      41433 non-null object
# DIRECCION             41433 non-null object
# tipo_prueba           41433 non-null object
# dtypes: int64(1), object(12)
# memory usage: 36.5 MB

# %%
for dtype in ['int','object','float']:
    selected_dtype = df.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Memoria promedio {} columnas: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Memoria promedio int columnas: 0.16 MB
# Memoria promedio object columnas: 2.78 MB
# Memoria promedio float columnas: 0.00 MB

# %%
optimized_data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41433 entries, 0 to 41432
# Data columns (total 13 columns):
# Cedula                41433 non-null int64
# HORA                  41433 non-null object
# NUM LABORATORIO       41433 non-null object
# Num_dia               41433 non-null object
# Nombre                41433 non-null object
# Provincia             41433 non-null object
# Canton                41433 non-null object
# Parroquia             41433 non-null object
# Zona                  41433 non-null object
# Nombre_institucion    41433 non-null object
# Amie_institucion      41433 non-null object
# DIRECCION             41433 non-null object
# tipo_prueba           41433 non-null object
# dtypes: int64(1), object(12)
# memory usage: 37.0 MB

# %%
data_2=['Cedula']
df[data_2]=df[data_2].replace(" ","0")
df[data_2]= df[data_2].astype(int)

# %%
dfn = pd.concat([
        df.select_dtypes([], ['object']),
        df.select_dtypes(['object']).apply(pd.Series.astype, dtype='category')
        ], axis=1).reindex_axis(df.columns, axis=1)
# Out:
# /home/djosuejj/en2/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#   after removing the cwd from sys.path.

# %%
dfn.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41433 entries, 0 to 41432
# Data columns (total 13 columns):
# Cedula                41433 non-null int64
# HORA                  41433 non-null category
# NUM LABORATORIO       41433 non-null category
# Num_dia               41433 non-null category
# Nombre                41433 non-null category
# Provincia             41433 non-null category
# Canton                41433 non-null category
# Parroquia             41433 non-null category
# Zona                  41433 non-null category
# Nombre_institucion    41433 non-null category
# Amie_institucion      41433 non-null category
# DIRECCION             41433 non-null category
# tipo_prueba           41433 non-null category
# dtypes: category(12), int64(1)
# memory usage: 6.0 MB
